# %% [markdown]
# Chargez les bibliothèques de fonctionnalités.

# %%
library(ggplot2)
library(tidyverse)

# %% [markdown]
# Ouvrir le tableau de données et le stocker dans la variable 'mimm_data'.

# %%
mimm_data <- read.csv('mimm_data.csv')
